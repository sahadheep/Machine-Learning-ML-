# %% [markdown]
# # Iris Dataset - Exploratory Data Analysis (EDA)
#
# ## Objective
#
# The objective of this notebook is to perform Exploratory Data Analysis (EDA) on the Iris dataset to understand its structure, identify missing values, analyze numerical and categorical features, detect outliers, and discover relationships between variables before applying machine learning models.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../datasets/Iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 6)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    str
# dtypes: float64(4), int64(1), str(1)
# memory usage: 7.2 KB

# %%
df.isnull().sum()
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species              str
# dtype: object

# %% [markdown]
# # Univariate Analysis on SepalLengthCm , sepalWidthCm , PetalLengthCm , PetalWidthCm

# %%
plt.figure(figsize = (8,5))
sns.histplot(data = df , x = "SepalLengthCm" , bins = 20 , kde = True)
plt.title("Distribution of Sepal Length")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize = (8,5))
sns.boxplot(data = df , x = "SepalLengthCm" , color = "blue")
plt.title("Distribution of Sepal Length")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize = (8,5))
sns.histplot(data = df , x = "SepalWidthCm" , bins = 20 , kde = True)
plt.title("Distribution of Sepal Width")
plt.xlabel("Sepal Width (cm)")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize = (8,5))
sns.boxplot(data = df , x = "SepalWidthCm" , color = "blue")
plt.title("Distribution of Sepal Width")
plt.xlabel("Sepal Width (cm)")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize = (8,5))
sns.histplot(data = df , x = "PetalLengthCm" , bins = 20 , kde = True)
plt.title("Distribution of Petal Length")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize = (8,5))
sns.boxplot(data = df , x = "PetalLengthCm" , color = "blue")
plt.title("Distribution of Petal Length")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize = (8,5))
sns.histplot(data = df , x = "PetalWidthCm" , bins = 20 , kde = True)
plt.title("Distribution of Petal Width")
plt.xlabel("Petal Width (cm)")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize = (8,5))
sns.boxplot(data = df , x = "PetalWidthCm" , color = "blue")
plt.title("Distribution of Petal Width")
plt.xlabel("Petal Width (cm)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # Relation of SepalLength and SepalWidth

# %%
plt.figure(figsize=(6,5))

sns.scatterplot(
    data=df,
    x="SepalLengthCm",
    y="SepalWidthCm",
    hue="Species"
)

plt.title("Sepal Length vs Sepal Width")
plt.show()

# %% [markdown]
# # Relation of PetalLength vs PetalWidth

# %%
plt.figure(figsize=(6,5))

sns.scatterplot(
    data=df,
    x="PetalLengthCm",
    y="PetalWidthCm",
    hue="Species"
)

plt.title("Petal Length vs Petal Width")
plt.show()

# %% [markdown]
# # Relation of Sepal Length vs Petal Length

# %%
plt.figure(figsize=(6,5))

sns.scatterplot(
    data=df,
    x="SepalLengthCm",
    y="PetalLengthCm",
    hue="Species"
)

plt.title("Sepal Length vs Petal Length")
plt.show()

# %% [markdown]
# # Relation of Sepal Width vs Petal Width

# %%
plt.figure(figsize=(6,5))

sns.scatterplot(
    data=df,
    x="SepalWidthCm",
    y="PetalWidthCm",
    hue="Species"
)

plt.title("Sepal Width vs Petal Width")
plt.show()

# %% [markdown]
# # Correlation Matrix

# %%
corr_matrix = df.drop(columns=["Id"]).corr(numeric_only=True)

corr_matrix
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
plt.figure(figsize=(6,5))

sns.heatmap(
    corr_matrix,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Heatmap")

plt.show()

# %%
sns.pairplot(
    df.drop(columns=["Id"]),
    hue="Species"
)
